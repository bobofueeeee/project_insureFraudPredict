# %%
import pandas as pd
data = pd.read_csv(r"data/test.csv")

# %%
data
# Out:
#      policy_id  age  customer_months policy_bind_date policy_state policy_csl  \
# 0       681822   60              473       2002-12-17            B   500/1000
# 1       301288   36              173       1994-01-15            B    100/300
# 2       212001   36              147       1995-12-19            B   500/1000
# 3       797680   24               71       1992-06-20            C   500/1000
# 4       789334   39              230       1996-11-28            C    250/500
# ..         ...  ...              ...              ...          ...        ...
# 295     663065   36               30       1999-08-18            B   500/1000
# 296     283767   47              285       2009-12-23            C    250/500
# 297     325099   39              256       1999-04-08            C   500/1000
# 298     465673   35               54       2010-09-08            C    100/300
# 299     913900   34              154       1990-09-27            C    100/300
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1134.96               0       445975
# 1                 1000                 916.20               0       469238
# 2                 1000                1175.74         5000000       595953
# 3                  500                1472.40               0       613103
# 4                 1000                1159.44         4000000       581581
# ..                 ...                    ...             ...          ...
# 295               2000                1384.15         9000000       593323
# 296                500                1590.78         7000000       447235
# 297               2000                1265.24               0       592069
# 298                500                1229.74               0       451451
# 299                500                1744.33               0       462941
#
#      ... bodily_injuries witnesses police_report_available total_claim_amount  \
# 0    ...               0         3                       ?              53253
# 1    ...               0         0                      NO              69401
# 2    ...               2         0                      NO              63919
# 3    ...               0         0                      NO              63173
# 4    ...               0         0                       ?               8847
# ..   ...             ...       ...                     ...                ...
# 295  ...               0         1                     YES               4507
# 296  ...               0         3                     YES              45909
# 297  ...               0         0                       ?              42293
# 298  ...               2         0                       ?              76875
# 299  ...               1         1                     YES              76269
#
#     injury_claim  property_claim  vehicle_claim auto_make      auto_model  \
# 0           5212           10251          39503      Saab              95
# 1           8309            8439          50012  Mercedes           ML350
# 2           5572           11477          42801     Dodge            Neon
# 3          12027            6500          43423     Dodge             RAM
# 4            904            1786           6138    Accura             RSX
# ..           ...             ...            ...       ...             ...
# 295          970             477           3339     Dodge            Neon
# 296         5599            5627          34598      Jeep  Grand Cherokee
# 297         5773            5491          34805     Dodge             RAM
# 298        14955            7312          59418    Nissan          Maxima
# 299         8260            8354          59141     Honda           Civic
#
#     auto_year
# 0        2006
# 1        2008
# 2        2009
# 3        2012
# 4        2003
# ..        ...
# 295      2002
# 296      1999
# 297      1997
# 298      2012
# 299      1998
#
# [300 rows x 37 columns]

# %%
## 1. 查
data['policy_id'] # Series
# Out:
#      policy_id
# 0       681822
# 1       301288
# 2       212001
# 3       797680
# 4       789334
# ..         ...
# 295     663065
# 296     283767
# 297     325099
# 298     465673
# 299     913900
#
# [300 rows x 1 columns]

# %%
data[['policy_id']] # DataFrame 只有一列
# Out:
#      policy_id
# 0       681822
# 1       301288
# 2       212001
# 3       797680
# 4       789334
# ..         ...
# 295     663065
# 296     283767
# 297     325099
# 298     465673
# 299     913900
#
# [300 rows x 1 columns]

# %%
data[['policy_id','age']] # DataFrame 有多列
# Out:
#      policy_id  age
# 0       681822   60
# 1       301288   36
# 2       212001   36
# 3       797680   24
# 4       789334   39
# ..         ...  ...
# 295     663065   36
# 296     283767   47
# 297     325099   39
# 298     465673   35
# 299     913900   34
#
# [300 rows x 2 columns]

# %%
rows = data.iloc[0:2,0:-1] ## 0:2 代表行，从0行开始，2行截至   0:-1  代表列，0行开始，倒数第一行截至
rows
# Out:
#    policy_id  age  customer_months policy_bind_date policy_state policy_csl  \
# 0     681822   60              473       2002-12-17            B   500/1000
# 1     301288   36              173       1994-01-15            B    100/300
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  ...  \
# 0               1000                1134.96               0       445975  ...
# 1               1000                 916.20               0       469238  ...
#
#   property_damage bodily_injuries witnesses police_report_available  \
# 0               ?               0         3                       ?
# 1               ?               0         0                      NO
#
#   total_claim_amount  injury_claim  property_claim vehicle_claim auto_make  \
# 0              53253          5212           10251         39503      Saab
# 1              69401          8309            8439         50012  Mercedes
#
#   auto_model
# 0         95
# 1      ML350
#
# [2 rows x 36 columns]

# %%
rows = data.iloc[0:2]  ## 后面不写，列，默认选中全部列
rows
# Out:
#    policy_id  age  customer_months policy_bind_date policy_state policy_csl  \
# 0     681822   60              473       2002-12-17            B   500/1000
# 1     301288   36              173       1994-01-15            B    100/300
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  ...  \
# 0               1000                1134.96               0       445975  ...
# 1               1000                 916.20               0       469238  ...
#
#   bodily_injuries witnesses police_report_available total_claim_amount  \
# 0               0         3                       ?              53253
# 1               0         0                      NO              69401
#
#   injury_claim  property_claim  vehicle_claim auto_make auto_model auto_year
# 0         5212           10251          39503      Saab         95      2006
# 1         8309            8439          50012  Mercedes      ML350      2008
#
# [2 rows x 37 columns]

# %%
rows = data.iloc[:,0:2]  ## 前面加逗号，：代表全部行
rows
# Out:
#      policy_id  age
# 0       681822   60
# 1       301288   36
# 2       212001   36
# 3       797680   24
# 4       789334   39
# ..         ...  ...
# 295     663065   36
# 296     283767   47
# 297     325099   39
# 298     465673   35
# 299     913900   34
#
# [300 rows x 2 columns]

# %%
rows = data.loc[0:2,['age','policy_id']]  ##loc 只能使用标签，不能使用索引
rows
# Out:
#    age  policy_id
# 0   60     681822
# 1   36     301288
# 2   36     212001

# %%
rows = data.loc[0:2] ## 同样: 后面不带，默认选中全部列
rows
# Out:
#    policy_id  age  customer_months policy_bind_date policy_state policy_csl  \
# 0     681822   60              473       2002-12-17            B   500/1000
# 1     301288   36              173       1994-01-15            B    100/300
# 2     212001   36              147       1995-12-19            B   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  ...  \
# 0               1000                1134.96               0       445975  ...
# 1               1000                 916.20               0       469238  ...
# 2               1000                1175.74         5000000       595953  ...
#
#   bodily_injuries witnesses police_report_available total_claim_amount  \
# 0               0         3                       ?              53253
# 1               0         0                      NO              69401
# 2               2         0                      NO              63919
#
#   injury_claim  property_claim  vehicle_claim auto_make auto_model auto_year
# 0         5212           10251          39503      Saab         95      2006
# 1         8309            8439          50012  Mercedes      ML350      2008
# 2         5572           11477          42801     Dodge       Neon      2009
#
# [3 rows x 37 columns]

# %%
rows = data.loc[:,['age','policy_id']] ## 同样:前面加入:，默认选中全部行
rows
# Out:
#      age  policy_id
# 0     60     681822
# 1     36     301288
# 2     36     212001
# 3     24     797680
# 4     39     789334
# ..   ...        ...
# 295   36     663065
# 296   47     283767
# 297   39     325099
# 298   35     465673
# 299   34     913900
#
# [300 rows x 2 columns]

# %%
rows = data.loc[0:2,['age','policy_id']]  ##loc 切片，多列
rows
# Out:
#    age  policy_id
# 0   60     681822
# 1   36     301288
# 2   36     212001

# %%
## 条件查询
conditonQuery = data[(data['age'] > 30) & (data['customer_months'] > 200)]  ## 最外层[]代表条件
conditonQuery.loc[:,'age'] = 10
conditonQuery
# Out:
#      policy_id  age  customer_months policy_bind_date policy_state policy_csl  \
# 0       681822   10              473       2002-12-17            B   500/1000
# 4       789334   10              230       1996-11-28            C    250/500
# 6       753093   10              258       2006-12-08            B    250/500
# 11      644825   10              223       2009-04-13            A   500/1000
# 12      770514   10              345       2009-12-12            A   500/1000
# ..         ...  ...              ...              ...          ...        ...
# 290     870334   10              341       1993-10-03            A    100/300
# 293     150112   10              344       2001-05-06            B   500/1000
# 294     936492   10              270       2006-07-09            A    250/500
# 296     283767   10              285       2009-12-23            C    250/500
# 297     325099   10              256       1999-04-08            C   500/1000
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1134.96               0       445975
# 4                 1000                1159.44         4000000       581581
# 6                  500                1242.43               0       433689
# 11                 500                1261.03               0       459954
# 12                 500                1270.97               0       637274
# ..                 ...                    ...             ...          ...
# 290               2000                1299.29               0       622445
# 293                500                1279.77               0       573535
# 294                500                1398.53               0       596084
# 296                500                1590.78         7000000       447235
# 297               2000                1265.24               0       592069
#
#      ... bodily_injuries witnesses police_report_available total_claim_amount  \
# 0    ...               0         3                       ?              53253
# 4    ...               0         0                       ?               8847
# 6    ...               1         0                      NO              60579
# 11   ...               2         1                      NO              54835
# 12   ...               2         0                       ?              49400
# ..   ...             ...       ...                     ...                ...
# 290  ...               0         3                      NO              53224
# 293  ...               0         3                      NO               5984
# 294  ...               1         2                      NO              45536
# 296  ...               0         3                     YES              45909
# 297  ...               0         0                       ?              42293
#
#     injury_claim  property_claim  vehicle_claim   auto_make      auto_model  \
# 0           5212           10251          39503        Saab              95
# 4            904            1786           6138      Accura             RSX
# 6           5386           10383          41953  Volkswagen           Jetta
# 11          5614            5369          42867         BMW              M5
# 12          5060            9890          35350   Chevrolet       Silverado
# ..           ...             ...            ...         ...             ...
# 290         5605           11144          37567    Mercedes            C300
# 293          943             993           4453        Ford          Fusion
# 294         4740            8938          31842        Audi              A5
# 296         5599            5627          34598        Jeep  Grand Cherokee
# 297         5773            5491          34805       Dodge             RAM
#
#     auto_year
# 0        2006
# 4        2003
# 6        2011
# 11       2011
# 12       2008
# ..        ...
# 290      2012
# 293      2011
# 294      2007
# 296      1999
# 297      1997
#
# [148 rows x 37 columns]
